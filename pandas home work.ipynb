# %%
import pandas as pd

# %%
df = pd.read_csv("AgentPerformance.csv")

# %%
df_login = pd.read_csv("Agent_Login_Report.csv")

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %% [markdown]
# #### 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
df5 = df[(df['day_name'] != 'Saturday') & (df['day_name'] != 'Sunday')]

# %%
df5[['Agent Name','Average Rating']][df5['week_day'] == 1]
# Out:
#                Agent Name  Average Rating
# 2088         Manjunatha A            4.83
# 2089       Jawala Prakash            4.17
# 2090       Saurabh Shukla            3.00
# 2091         Jayant Kumar            4.25
# 2092  Boktiar Ahmed Bappy            4.45
# ...                   ...             ...
# 2155    Sowmiya Sivakumar            0.00
# 2156              Nitin M            0.00
# 2157               Vivek             0.00
# 2158        Ayushi Mishra            0.00
# 2159   Chaitra K Hiremath            0.00
#
# [72 rows x 2 columns]

# %%
df5[['Agent Name','Average Rating']][df5['week_day'] == 2]
# Out:
#                Agent Name  Average Rating
# 1584         Nishtha Jain            5.00
# 1585       Khushboo Priya            4.33
# 1586         Manjunatha A            4.25
# 1587       Ishawant Kumar            5.00
# 1588               Vivek             3.40
# ...                   ...             ...
# 1939          Madhulika G            0.00
# 1940   Chaitra K Hiremath            0.00
# 1941       Jawala Prakash            3.80
# 1942  Boktiar Ahmed Bappy            4.50
# 1943         Manjunatha A            4.27
#
# [360 rows x 2 columns]

# %%
df5[['Agent Name','Average Rating']][df5['week_day'] == 3]
# Out:
#           Agent Name  Average Rating
# 1080   Sandipan Saha            4.25
# 1081  Khushboo Priya            4.75
# 1082    Nishtha Jain            5.00
# 1083  Ishawant Kumar            5.00
# 1084    Manjunatha A            4.44
# ...              ...             ...
# 1435  Jawala Prakash            4.30
# 1436    Nishtha Jain            4.12
# 1437  Khushboo Priya            4.27
# 1438    Manjunatha A            4.00
# 1439  Ishawant Kumar            3.67
#
# [360 rows x 2 columns]

# %%
df5[['Agent Name','Average Rating']][df5['week_day'] == 4]
# Out:
#               Agent Name  Average Rating
# 576   Shivananda Sonwane            4.44
# 577  Boktiar Ahmed Bappy            4.24
# 578        Prateek _iot             4.20
# 579          Aditya_iot             5.00
# 580        Nandani Gupta            4.53
# ..                   ...             ...
# 931         Manjunatha A            4.57
# 932  Boktiar Ahmed Bappy            4.12
# 933         Nishtha Jain            4.11
# 934       Ishawant Kumar            4.67
# 935       Khushboo Priya            5.00
#
# [360 rows x 2 columns]

# %%
df5[['Agent Name','Average Rating']][df5['week_day'] == 5]
# Out:
#               Agent Name  Average Rating
# 72    Shivananda Sonwane            4.67
# 73   Boktiar Ahmed Bappy            4.00
# 74      Shiva Srivastava            4.17
# 75           Muskan Garg            5.00
# 76         Prateek _iot             3.75
# ..                   ...             ...
# 427       Jawala Prakash            4.64
# 428              Maitry             5.00
# 429     Deepranjan Gupta            4.69
# 430       Ishawant Kumar            4.44
# 431        Ayushi Mishra            4.43
#
# [360 rows x 2 columns]

# %%
df_login['Total_Duration'] = pd.to_timedelta(df_login.Duration)

# %% [markdown]
# #### 2 .Total working days for each agents

# %%
df2 = df[df['Total Chats']>0]

# %%
df2.groupby('Agent Name')['Date'].count()
# Out:
# Agent Name
# Aditya Shinde             12
# Aditya_iot                17
# Ameya Jain                15
# Anirudh                    7
# Ankitjha                   3
# Anurag Tiwari              2
# Aravind                   14
# Ashad Nasim                2
# Ayushi Mishra             24
# Bharath                   19
# Boktiar Ahmed Bappy       26
# Chaitra K Hiremath         6
# Deepranjan Gupta          21
# Dibyanshu                  1
# Harikrishnan Shaji        19
# Hitesh Choudhary           1
# Hrisikesh Neogi           21
# Ishawant Kumar            24
# Jawala Prakash            25
# Jayant Kumar               8
# Jaydeep Dixit             21
# Khushboo Priya            26
# Madhulika G               24
# Mahak                      1
# Mahesh Sarade             18
# Maitry                    20
# Maneesh                    3
# Manjunatha A              25
# Mithun S                  18
# Mukesh                     2
# Mukesh Rao                 3
# ...

# %% [markdown]
# #### 3. Total query that you hvae taken

# %%
df2.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Aditya Shinde             277
# Aditya_iot                231
# Ameya Jain                322
# Anirudh                    81
# Ankitjha                    5
# Anurag Tiwari               4
# Aravind                   366
# Ashad Nasim                18
# Ayushi Mishra             514
# Bharath                   369
# Boktiar Ahmed Bappy       452
# Chaitra K Hiremath         64
# Deepranjan Gupta          493
# Dibyanshu                   1
# Harikrishnan Shaji        381
# Hitesh Choudhary            1
# Hrisikesh Neogi           578
# Ishawant Kumar            338
# Jawala Prakash            439
# Jayant Kumar              127
# Jaydeep Dixit             512
# Khushboo Priya            446
# Madhulika G               469
# Mahak                       7
# Mahesh Sarade             364
# Maitry                    542
# Maneesh                     4
# Manjunatha A              413
# Mithun S                  503
# Mukesh                     19
# ...

# %% [markdown]
# #### 4. Total Feedback that you have received

# %%
 df[["Total Feedback"]]
# Out:
#       Total Feedback
# 0                  9
# 1                  7
# 2                 11
# 3                  7
# 4                  6
# ...              ...
# 2155               0
# 2156               0
# 2157               0
# 2158               0
# 2159               0
#
# [2160 rows x 1 columns]

# %% [markdown]
# #### 5. a agent name who have average rating between 3.5 to 4

# %%
df[(df['Average Rating']>3.5) & (df['Average Rating']<4)][['Agent Name','Average Rating']]
# Out:
#                Agent Name  Average Rating
# 4                  Swati             3.67
# 10           Manjunatha A            3.60
# 76          Prateek _iot             3.75
# 78          Nandani Gupta            3.79
# 80          Jaydeep Dixit            3.95
# ...                   ...             ...
# 1869  Boktiar Ahmed Bappy            3.78
# 1874        Ayushi Mishra            3.80
# 1941       Jawala Prakash            3.80
# 2021        Aditya Shinde            3.54
# 2023     Deepranjan Gupta            3.71
#
# [78 rows x 2 columns]

# %% [markdown]
# #### 6 . Agent name who have rating lesss then 3.5

# %%
df[df['Average Rating']<3.5][['Agent Name','Average Rating']]
# Out:
#               Agent Name  Average Rating
# 1          Nandani Gupta            3.14
# 19      Hitesh Choudhary            0.00
# 20            Sanjeevan             0.00
# 21              Anirudh             0.00
# 22      Shiva Srivastava            0.00
# ...                  ...             ...
# 2155   Sowmiya Sivakumar            0.00
# 2156             Nitin M            0.00
# 2157              Vivek             0.00
# 2158       Ayushi Mishra            0.00
# 2159  Chaitra K Hiremath            0.00
#
# [1474 rows x 2 columns]

# %% [markdown]
# #### 7. Agent name who have rating more then 4.5

# %%
df[df['Average Rating']>4.5][['Agent Name','Average Rating']]
# Out:
#               Agent Name  Average Rating
# 2             Ameya Jain            4.55
# 3          Mahesh Sarade            4.71
# 5                Mukesh             4.62
# 6        Saikumarreddy N            5.00
# 7          Sanjeev Kumar            5.00
# ...                  ...             ...
# 2100      Shubham Sharma            5.00
# 2101       Jaydeep Dixit            4.77
# 2102  Shivananda Sonwane            4.86
# 2103      Khushboo Priya            4.61
# 2104     Hrisikesh Neogi            4.56
#
# [307 rows x 2 columns]

# %% [markdown]
# #### 8 . how many feedaback agents have received more then 4.5 average

# %%
df[df['Average Rating']>4.5]['Total Feedback'].count()
# Out:
# 307

# %% [markdown]
# #### 9 . average weekly response time for each agent

# %%
df['Convert_Date_Time'] = pd.to_datetime(df['Date'])

# %%
df['day_name'] = df['Convert_Date_Time'].dt.day_name()

# %%
def week_number_of_month(date_value):
     return (date_value.isocalendar()[1] - date_value.replace(day=1).isocalendar()[1] + 1)

# %%
df['week_day'] = df['Convert_Date_Time'].apply(week_number_of_month)
df.head(3)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
#
#   Average Resolution Time  Average Rating  Total Feedback Convert_Date_Time  \
# 0                00:04:20            4.11               9        2022-07-30
# 1                00:28:25            3.14               7        2022-07-30
# 2                00:11:36            4.55              11        2022-07-30
#
#    week_day
# 0         5
# 1         5
# 2         5

# %%
df[['Agent Name','Average Response Time']][df['week_day'] == 1]
# Out:
#                Agent Name Average Response Time
# 1944       Jawala Prakash              00:01:08
# 1945  Boktiar Ahmed Bappy              00:00:53
# 1946         Manjunatha A              00:00:49
# 1947        Aditya Shinde              00:01:20
# 1948             Bharath               00:00:21
# ...                   ...                   ...
# 2155    Sowmiya Sivakumar              00:00:00
# 2156              Nitin M              00:00:00
# 2157               Vivek               00:00:00
# 2158        Ayushi Mishra              00:00:00
# 2159   Chaitra K Hiremath              00:00:00
#
# [216 rows x 2 columns]

# %%
df[['Agent Name','Average Response Time']][df['week_day'] == 2]
# Out:
#                Agent Name Average Response Time
# 1440       Ishawant Kumar              00:01:14
# 1441         Nishtha Jain              00:00:56
# 1442       Khushboo Priya              00:01:05
# 1443         Manjunatha A              00:01:03
# 1444   Harikrishnan Shaji              00:00:43
# ...                   ...                   ...
# 1939          Madhulika G              00:00:00
# 1940   Chaitra K Hiremath              00:00:00
# 1941       Jawala Prakash              00:00:44
# 1942  Boktiar Ahmed Bappy              00:00:56
# 1943         Manjunatha A              00:00:45
#
# [504 rows x 2 columns]

# %%
df[['Agent Name','Average Response Time']][df['week_day'] == 3]
# Out:
#                Agent Name Average Response Time
# 936        Ishawant Kumar              00:01:37
# 937        Khushboo Priya              00:00:46
# 938          Nishtha Jain              00:00:56
# 939   Boktiar Ahmed Bappy              00:01:42
# 940          Manjunatha A              00:00:34
# ...                   ...                   ...
# 1435       Jawala Prakash              00:01:19
# 1436         Nishtha Jain              00:01:11
# 1437       Khushboo Priya              00:01:01
# 1438         Manjunatha A              00:00:43
# 1439       Ishawant Kumar              00:01:19
#
# [504 rows x 2 columns]

# %%
df[['Agent Name','Average Response Time']][df['week_day'] == 4]
# Out:
#               Agent Name Average Response Time
# 432     Shiva Srivastava              00:00:47
# 433       Jawala Prakash              00:01:22
# 434     Deepranjan Gupta              00:01:13
# 435       Ishawant Kumar              00:01:09
# 436        Jaydeep Dixit              00:00:40
# ..                   ...                   ...
# 931         Manjunatha A              00:00:52
# 932  Boktiar Ahmed Bappy              00:02:08
# 933         Nishtha Jain              00:01:11
# 934       Ishawant Kumar              00:01:06
# 935       Khushboo Priya              00:00:45
#
# [504 rows x 2 columns]

# %%
df[['Agent Name','Average Response Time']][df['week_day'] == 5]
# Out:
#            Agent Name Average Response Time
# 0        Prerna Singh              00:00:38
# 1       Nandani Gupta              00:01:15
# 2          Ameya Jain              00:00:30
# 3       Mahesh Sarade              00:01:04
# 4              Swati               00:01:11
# ..                ...                   ...
# 427    Jawala Prakash              00:01:21
# 428           Maitry               00:05:32
# 429  Deepranjan Gupta              00:01:20
# 430    Ishawant Kumar              00:01:01
# 431     Ayushi Mishra              00:01:07
#
# [432 rows x 2 columns]

# %% [markdown]
# #### 10 . average weekely resolution time for each agents

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback',
#        'Convert_Date_Time', 'week_day'],
#       dtype='object')

# %%
df[['Agent Name','Average Resolution Time']][df['week_day'] == 1]
# Out:
#                Agent Name Average Resolution Time
# 1944       Jawala Prakash                00:13:45
# 1945  Boktiar Ahmed Bappy                00:09:34
# 1946         Manjunatha A                00:31:56
# 1947        Aditya Shinde                00:26:29
# 1948             Bharath                 00:06:34
# ...                   ...                     ...
# 2155    Sowmiya Sivakumar                00:00:00
# 2156              Nitin M                00:00:00
# 2157               Vivek                 00:00:00
# 2158        Ayushi Mishra                00:00:00
# 2159   Chaitra K Hiremath                00:00:00
#
# [216 rows x 2 columns]

# %%
df[['Agent Name','Average Resolution Time']][df['week_day'] == 2]
# Out:
#                Agent Name Average Resolution Time
# 1440       Ishawant Kumar                00:22:34
# 1441         Nishtha Jain                00:14:57
# 1442       Khushboo Priya                00:10:43
# 1443         Manjunatha A                00:29:58
# 1444   Harikrishnan Shaji                00:10:02
# ...                   ...                     ...
# 1939          Madhulika G                00:00:00
# 1940   Chaitra K Hiremath                00:00:00
# 1941       Jawala Prakash                00:02:28
# 1942  Boktiar Ahmed Bappy                00:08:52
# 1943         Manjunatha A                00:19:02
#
# [504 rows x 2 columns]

# %%
df[['Agent Name','Average Resolution Time']][df['week_day'] == 3]
# Out:
#                Agent Name Average Resolution Time
# 936        Ishawant Kumar                00:11:46
# 937        Khushboo Priya                00:13:26
# 938          Nishtha Jain                00:10:51
# 939   Boktiar Ahmed Bappy                00:23:37
# 940          Manjunatha A                00:16:16
# ...                   ...                     ...
# 1435       Jawala Prakash                00:18:54
# 1436         Nishtha Jain                00:12:22
# 1437       Khushboo Priya                00:15:44
# 1438         Manjunatha A                00:25:53
# 1439       Ishawant Kumar                00:21:42
#
# [504 rows x 2 columns]

# %%
df[['Agent Name','Average Resolution Time']][df['week_day'] == 4]
# Out:
#               Agent Name Average Resolution Time
# 432     Shiva Srivastava                00:04:18
# 433       Jawala Prakash                00:29:59
# 434     Deepranjan Gupta                00:32:51
# 435       Ishawant Kumar                00:12:37
# 436        Jaydeep Dixit                00:28:28
# ..                   ...                     ...
# 931         Manjunatha A                00:16:04
# 932  Boktiar Ahmed Bappy                00:15:33
# 933         Nishtha Jain                00:13:12
# 934       Ishawant Kumar                00:11:09
# 935       Khushboo Priya                00:07:53
#
# [504 rows x 2 columns]

# %%
df[['Agent Name','Average Resolution Time']][df['week_day'] == 5]
# Out:
#            Agent Name Average Resolution Time
# 0        Prerna Singh                00:04:20
# 1       Nandani Gupta                00:28:25
# 2          Ameya Jain                00:11:36
# 3       Mahesh Sarade                00:15:46
# 4              Swati                 00:16:33
# ..                ...                     ...
# 427    Jawala Prakash                00:18:33
# 428           Maitry                 00:10:07
# 429  Deepranjan Gupta                00:17:56
# 430    Ishawant Kumar                00:30:31
# 431     Ayushi Mishra                00:26:14
#
# [432 rows x 2 columns]

# %% [markdown]
# #### 11 . list of all agents name

# %%
agent_name_list = df['Agent Name'].to_list()

# %%
agent_name_list
# Out:
# ['Prerna Singh',
#  'Nandani Gupta',
#  'Ameya Jain',
#  'Mahesh Sarade',
#  'Swati ',
#  'Mukesh ',
#  'Saikumarreddy N',
#  'Sanjeev Kumar',
#  'Shubham Sharma',
#  'Nishtha Jain',
#  'Manjunatha A',
#  'Khushboo Priya',
#  'Suraj S Bilgi',
#  'Harikrishnan Shaji',
#  'Hrisikesh Neogi',
#  'Shivan K',
#  'Sowmiya Sivakumar',
#  'Madhulika G',
#  'Mithun S',
#  'Hitesh Choudhary',
#  'Sanjeevan ',
#  'Anirudh ',
#  'Shiva Srivastava',
#  'Dibyanshu ',
#  'Ashish ',
#  'Uday Mishra',
#  'Aditya Shinde',
#  'Jayant Kumar',
#  'Aditya_iot ',
#  'Prabir Kumar Satapathy',
#  'Saurabh Shukla',
#  'Wasim ',
#  'Samprit ',
#  'Maitry ',
#  'Abhishek ',
#  'Rishav Dash',
#  'Aravind ',
#  'Tarun ',
#  'Muskan Garg',
#  'Ankit Sharma',
#  'Bharath ',
#  'Ashad Nasim',
#  'Vasanth P',
#  'Aditya ',
#  'Amersh ',
#  'Sandipan Saha',
#  'Ineuron Intelligence ',
#  'Mahak ',
#  'Mukesh Rao ',
#  'Zeeshan ',
#  'Rishav Dash',
#  'Anurag Tiwari',
#  'Ankitjha ',
#  'Saif Khan',
#  'Jaydeep Dixit',
# ...

# %% [markdown]
# #### 12 . percentage of chat on which they have received a feedback

# %%
total_chat = df['Total Chats'].sum()

# %%
total_feedback = df['Total Feedback'].sum()

# %%
percentage_of_chat = (total_feedback / total_chat) * 100

# %%
percentage_of_chat
# Out:
# 62.900815217391305

# %% [markdown]
# #### 13 . Total contributation hour for each and every agents weekly basis

# %%
def week_number_of_month(date_value):
     return (date_value.isocalendar()[1] - date_value.replace(day=1).isocalendar()[1] + 1)

# %%
df_login['Convert_Date_Time'] = pd.to_datetime(df_login['Date'])

# %%
df_login['week_day'] = df_login['Convert_Date_Time'].apply(week_number_of_month)

# %%
df_login['Total_Duration'] = pd.to_timedelta(df_login.Duration)

# %%
df_login.groupby('Agent')['Total_Duration'].sum()

# %%
df_login_firstweek = df_login[df_login['week_day'] == 1]

# %%
df_login_firstweek.groupby('Agent')['Total_Duration'].sum()
# Out:
# Agent
# Tarun    21 days 10:08:20
# Name: Total_Duration, dtype: timedelta64[ns]

# %%
df_login_secondweek = df_login[df_login['week_day'] == 2]

# %%
df_login_secondweek.groupby('Agent')['Total_Duration'].sum()
# Out:
# Series([], Name: Total_Duration, dtype: timedelta64[ns])

# %%
df_login_thirdweek = df_login[df_login['week_day'] == 3]

# %%
df_login_thirdweek.groupby('Agent')['Total_Duration'].sum()
# Out:
# Series([], Name: Total_Duration, dtype: timedelta64[ns])

# %%
df_login_fourweek = df_login[df_login['week_day'] == 4]

# %%
df_login_fourweek.groupby('Agent')['Total_Duration'].sum()
# Out:
# Agent
# Aditya_iot               0 days 06:05:43
# Ameya Jain               1 days 00:04:59
# Anurag Tiwari            0 days 00:15:52
# Aravind                  1 days 00:14:08
# Ayushi Mishra            0 days 17:47:25
# Bharath                  1 days 00:04:15
# Boktiar Ahmed Bappy      0 days 17:45:01
# Chaitra K Hiremath       0 days 02:14:05
# Deepranjan Gupta         2 days 00:59:47
# Dibyanshu                1 days 03:44:38
# Harikrishnan Shaji       0 days 21:26:18
# Hrisikesh Neogi          1 days 02:53:29
# Hyder Abbas              0 days 00:20:10
# Ineuron Intelligence     0 days 01:26:55
# Ishawant Kumar           1 days 01:43:15
# Jawala Prakash           1 days 00:20:24
# Jaydeep Dixit            1 days 17:54:52
# Khushboo Priya           0 days 21:42:57
# Madhulika G              1 days 01:51:03
# Mahesh Sarade            1 days 01:28:59
# Maitry                   1 days 00:39:28
# Manjunatha A             0 days 18:21:04
# Mithun S                 0 days 17:22:47
# ...

# %%
df_login_fiveweek = df_login[df_login['week_day'] == 5]

# %%
df_login_fiveweek.groupby('Agent')['Total_Duration'].sum()
# Out:
# Agent
# Aditya Shinde            0 days 00:02:10
# Aditya_iot               0 days 09:38:09
# Amersh                   0 days 03:03:50
# Ameya Jain               0 days 17:59:33
# Ankitjha                 0 days 02:16:01
# Anurag Tiwari            0 days 02:30:52
# Aravind                  0 days 00:03:49
# Ayushi Mishra            0 days 20:19:53
# Bharath                  1 days 00:00:21
# Boktiar Ahmed Bappy      0 days 22:31:06
# Chaitra K Hiremath       1 days 08:05:27
# Deepranjan Gupta         2 days 09:16:44
# Dibyanshu                1 days 00:51:07
# Harikrishnan Shaji       1 days 08:16:35
# Hrisikesh Neogi          1 days 06:40:38
# Hyder Abbas              0 days 00:03:07
# Ishawant Kumar           1 days 02:03:29
# Jawala Prakash           0 days 22:03:44
# Jaydeep Dixit            0 days 17:55:34
# Khushboo Priya           0 days 21:50:34
# Madhulika G              0 days 20:12:34
# Mahesh Sarade            0 days 17:26:20
# Maitry                   0 days 06:17:14
# ...

# %% [markdown]
# #### 14. total percentage of active hour for a month

# %%
def percentage_calculation(time):
    time = str(time)
    h, m, s = time.split(':')
    sec = int(h) * 3600 + int(m) * 60 + int(s)
    time_per = (sec/86400)*100
    return time_per

# %%
df_login["Total_Duration_Percentage"] = df_login['Duration'].apply(percentage_calculation)

# %%
df_login['week_day'] = df_login['Convert_Date_Time'].apply(week_number_of_month)

# %%
df_login['Total_Duration_Percentage'].sum()
# Out:
# 9083.185185185186

# %%
df_login.drop('Total_Duration',axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
#
#   Average Resolution Time  Average Rating  Total Feedback Convert_Date_Time  \
# 0                00:04:20            4.11               9        2022-07-30
# 1                00:28:25            3.14               7        2022-07-30
# 2                00:11:36            4.55              11        2022-07-30
#
#    week_day  day_name
# 0         5  Saturday
# 1         5  Saturday
# 2         5  Saturday
